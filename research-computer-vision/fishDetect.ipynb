# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# D:\Anacoda\Anacode\envs\ComputerVs1\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\Anacoda\Anacode\envs\ComputerVs1\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# D:\Anacoda\Anacode\envs\ComputerVs1\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
model = YOLO("yolov8n.pt")
#results = model.predict(source ='./cat1.jpeg',save=True)
results = model.train(data ="data.yaml",epochs =100)
# Out:
# New https://pypi.org/project/ultralytics/8.0.132 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.58  Python-3.9.16 torch-2.0.0+cpu CPU
# ...

# %%
# !yolo task=detect mode=predict model='./runs/detect/train6/weights/best.pt' source='fish.mp4' save = True, save_txt =True
# Out:
# D:\Anacoda\Anacode\envs\ComputerVs1\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\Anacoda\Anacode\envs\ComputerVs1\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# D:\Anacoda\Anacode\envs\ComputerVs1\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# WARNING  'save=True,' does not require trailing comma ',', updating to 'save=True'.
# Ultralytics YOLOv8.0.58  Python-3.9.16 torch-2.0.0+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/1140) C:\Users\ADMIN\Desktop\Computer Vision\lesson4\fish.mp4: 480x640 11 fishs, 221.3ms
# video 1/1 (2/1140) C:\Users\ADMIN\Desktop\Computer Vision\lesson4\fish.mp4: 480x640 12 fishs, 162.5ms
# video 1/1 (3/1140) C:\Users\ADMIN\Desktop\Computer Vision\lesson4\fish.mp4: 480x640 10 fishs, 207.3ms
# ...
